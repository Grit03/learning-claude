# %%
# 의존성 설치
# %pip install anthropic python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages, system=None):
  params = {
    "model": model,
    "max_tokens": 1000,
    "messages": messages
  }
  if system:
    params["system"] = system
  
  answer = client.messages.create(**params)

  return answer.content[0].text

# %%
messages = []

add_user_message(messages, "문자열 안에 중복 문자가 있는지 검사하는 파이썬 함수를 작성해봐")

answer = chat(messages)

answer
# Out:
# '# 문자열 중복 문자 검사 함수\n\n## 다양한 방법으로 구현\n\n### 방법 1: `set` 활용 (가장 간단)\n\n```python\ndef has_duplicate_chars(s: str) -> bool:\n    """문자열에 중복 문자가 있으면 True 반환"""\n    return len(s) != len(set(s))\n\n# 테스트\nprint(has_duplicate_chars("hello"))   # True  (l 중복)\nprint(has_duplicate_chars("python"))  # False (중복 없음)\nprint(has_duplicate_chars("world"))   # True  (l 중복)\n```\n\n---\n\n### 방법 2: 딕셔너리로 중복 문자 찾기\n\n```python\ndef find_duplicate_chars(s: str) -> dict:\n    """중복된 문자와 등장 횟수를 딕셔너리로 반환"""\n    char_count = {}\n\n    for char in s:\n        char_count[char] = char_count.get(char, 0) + 1\n\n    # 2번 이상 등장한 문자만 필터링\n    duplicates = {char: count for char, count in char_count.items() if count > 1}\n\n    return duplicates\n\n# 테스트\nprint(find_duplicate_chars("hello"))        # {\'l\': 2}\nprint(find_duplicate_chars("programming"))  # {\'r\': 2, \'g\': 2, \'m\': 2}\nprint(find_duplicate_chars("python"))       # {}\n```\n\n---\n\n### 방법 3: `Counter` 활용 (깔끔한 방법)\n\n```python\nfrom collectio
# ...

# %%
messages = []

add_user_message(messages, "문자열 안에 중복 문자가 있는지 검사하는 파이썬 함수를 작성해봐")

answer = chat(messages=messages, system="너는 아주 간결하게 코드를 작성하는 파이썬 개발자야.")

answer
# Out:
# '## 중복 문자 검사 함수\n\n```python\ndef has_duplicate(s: str) -> bool:\n    return len(s) != len(set(s))\n```\n\n## 사용 예시\n\n```python\nprint(has_duplicate("hello"))   # True  (\'l\' 중복)\nprint(has_duplicate("world"))   # False\nprint(has_duplicate("python"))  # False\nprint(has_duplicate("apple"))   # True  (\'p\' 중복)\n```\n\n## 어떤 문자가 중복인지도 알고 싶다면\n\n```python\ndef find_duplicates(s: str) -> set:\n    seen = set()\n    return {c for c in s if c in seen or seen.add(c)}\n\nprint(find_duplicates("hello"))  # {\'l\'}\nprint(find_duplicates("apple"))  # {\'p\'}\n```\n\n**핵심 원리**\n- `set`은 중복을 허용하지 않으므로, 문자열을 `set`으로 변환했을 때 길이가 줄어들면 중복이 있다는 뜻'
